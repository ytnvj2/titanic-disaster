# %%
import pandas as pd,numpy as np,os

# %%
raw_data_path=os.path.join(os.path.pardir,'data','raw')
train_data_path=os.path.join(raw_data_path,'train.csv')
test_data_path=os.path.join(raw_data_path,'test.csv')

# %%
train_df=pd.read_csv(train_data_path,index_col='PassengerId')
test_df=pd.read_csv(test_data_path,index_col='PassengerId')

# %%
type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
# Pclass      418 non-null int64
# Name        418 non-null object
# Sex         418 non-null object
# Age         332 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Ticket      418 non-null object
# Fare        417 non-null float64
# Cabin       91 non-null object
# Embarked    418 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
test_df['Survived']=-888

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 11 columns):
# Pclass      418 non-null int64
# Name        418 non-null object
# Sex         418 non-null object
# Age         332 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Ticket      418 non-null object
# Fare        417 non-null float64
# Cabin       91 non-null object
# Embarked    418 non-null object
# Survived    418 non-null int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 39.2+ KB

# %%
df=pd.concat((test_df,train_df),axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 892 to 891
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1307 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB

# %%
df.header()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-14774251d94e> in <module>()
# ----> 1 df.header()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'header'

# %%
df.tail()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 882          33.0   NaN        S   7.8958
# 883          22.0   NaN        S  10.5167
# 884          28.0   NaN        S  10.5000
# 885          25.0   NaN        S   7.0500
# 886          39.0   NaN        Q  29.1250
# 887          27.0   NaN        S  13.0000
# 888          19.0   B42        S  30.0000
# 889           NaN   NaN        S  23.4500
# 890          26.0  C148        C  30.0000
# 891          32.0   NaN        Q   7.7500
#
#                                                  Name  Parch  Pclass     Sex  \
# PassengerId
# 882                                Markun, Mr. Johann      0       3    male
# 883                      Dahlberg, Miss. Gerda Ulrika      0       3  female
# 884                     Banfield, Mr. Frederick James      0       2    male
# 885                            Sutehall, Mr. Henry Jr      0       3    male
# 886              Rice, Mrs. William (Margaret Norton)      5       3  female
# ...

# %%
#column selection using .
df.Name
#gives pandas series
# Out:
# PassengerId
# 892                                     Kelly, Mr. James
# 893                     Wilkes, Mrs. James (Ellen Needs)
# 894                            Myles, Mr. Thomas Francis
# 895                                     Wirz, Mr. Albert
# 896         Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897                           Svensson, Mr. Johan Cervin
# 898                                 Connolly, Miss. Kate
# 899                         Caldwell, Mr. Albert Francis
# 900            Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 901                              Davies, Mr. John Samuel
# 902                                     Ilieff, Mr. Ylio
# 903                           Jones, Mr. Charles Cresson
# 904        Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 905                                 Howard, Mr. Benjamin
# 906    Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 907        del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# ...

# %%
df['Name']
#gives pandas series
# Out:
# PassengerId
# 892                                     Kelly, Mr. James
# 893                     Wilkes, Mrs. James (Ellen Needs)
# 894                            Myles, Mr. Thomas Francis
# 895                                     Wirz, Mr. Albert
# 896         Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897                           Svensson, Mr. Johan Cervin
# 898                                 Connolly, Miss. Kate
# 899                         Caldwell, Mr. Albert Francis
# 900            Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 901                              Davies, Mr. John Samuel
# 902                                     Ilieff, Mr. Ylio
# 903                           Jones, Mr. Charles Cresson
# 904        Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 905                                 Howard, Mr. Benjamin
# 906    Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 907        del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# ...

# %%
df[['Name','Pclass']]
#gives pandas dataframe
#can add attributes in [['Name','Pclass']]
# Out:
#                                                           Name  Pclass
# PassengerId
# 892                                           Kelly, Mr. James       3
# 893                           Wilkes, Mrs. James (Ellen Needs)       3
# 894                                  Myles, Mr. Thomas Francis       2
# 895                                           Wirz, Mr. Albert       3
# 896               Hirvonen, Mrs. Alexander (Helga E Lindqvist)       3
# 897                                 Svensson, Mr. Johan Cervin       3
# 898                                       Connolly, Miss. Kate       3
# 899                               Caldwell, Mr. Albert Francis       2
# 900                  Abrahim, Mrs. Joseph (Sophie Halaut Easu)       3
# 901                                    Davies, Mr. John Samuel       3
# 902                                           Ilieff, Mr. Ylio       3
# 903                                 Jones, Mr. Charles Cresson       1
# ...

# %%
df[1:4]
# Out:
#               Age Cabin Embarked    Fare                              Name  \
# PassengerId
# 893          47.0   NaN        S  7.0000  Wilkes, Mrs. James (Ellen Needs)
# 894          62.0   NaN        Q  9.6875         Myles, Mr. Thomas Francis
# 895          27.0   NaN        S  8.6625                  Wirz, Mr. Albert
#
#              Parch  Pclass     Sex  SibSp  Survived  Ticket
# PassengerId
# 893              0       3  female      1      -888  363272
# 894              0       2    male      0      -888  240276
# 895              0       3    male      0      -888  315154

# %%
df[1:4]
#slicing only works for rows
# Out:
#               Age Cabin Embarked    Fare                              Name  \
# PassengerId
# 893          47.0   NaN        S  7.0000  Wilkes, Mrs. James (Ellen Needs)
# 894          62.0   NaN        Q  9.6875         Myles, Mr. Thomas Francis
# 895          27.0   NaN        S  8.6625                  Wirz, Mr. Albert
#
#              Parch  Pclass     Sex  SibSp  Survived  Ticket
# PassengerId
# 893              0       3  female      1      -888  363272
# 894              0       2    male      0      -888  240276
# 895              0       3    male      0      -888  315154

# %%
df.loc[1]
#gives pandas series
df.loc[[1]]
#gives row
df.loc[1:4,['Name','Pclass']]
#row slicing works with loc and col names specified
df.loc[1:4,'Name':'Pclass']
#col slicing with labels
df.loc[5:10,]
#no cols can be specified
df.loc[:,'Age':'Name']
#no rows specified
# Out:
#               Age        Cabin Embarked     Fare  \
# PassengerId
# 892          34.5          NaN        Q   7.8292
# 894          62.0          NaN        Q   9.6875
# 895          27.0          NaN        S   8.6625
# 897          14.0          NaN        S   9.2250
# 899          26.0          NaN        S  29.0000
# 901          21.0          NaN        S  24.1500
# 902           NaN          NaN        S   7.8958
# 903          46.0          NaN        S  26.0000
# 905          63.0          NaN        S  26.0000
# 908          35.0          NaN        Q  12.3500
# 909          21.0          NaN        C   7.2250
# 912          55.0          NaN        C  59.4000
# 913           9.0          NaN        S   3.1708
# 915          21.0          NaN        C  61.3792
# 917          50.0          NaN        S  14.5000
# 919          22.5          NaN        C   7.2250
# 920          41.0          A21        S  30.5000
# 921           NaN          NaN        C  21.6792
# ...

# %%
df.iloc[1:4,1:5]
#uses only index based slicing
df.iloc[[1,4],[1,5]]
#specifies only indexes to select
df.iloc[1,4]
#col and rows specified
# Out:
# 'Wilkes, Mrs. James (Ellen Needs)'

# %%
df.loc[(df.Sex=='male')&(df.Pclass==1),:]
#bool expression to select rows with combination No && only &, no 'and'.
# Out:
#               Age            Cabin Embarked      Fare  \
# PassengerId
# 903          46.0              NaN        S   26.0000
# 912          55.0              NaN        C   59.4000
# 915          21.0              NaN        C   61.3792
# 920          41.0              A21        S   30.5000
# 926          30.0              C78        C   57.7500
# 933           NaN              D34        S   26.5500
# 938          45.0               A9        C   29.7000
# 942          24.0              C31        S   60.0000
# 956          13.0  B57 B59 B63 B66        C  262.3750
# 959          47.0              NaN        S   42.4000
# 960          31.0              C53        C   28.5375
# 965          28.5              D43        C   27.7208
# 967          32.5             C132        C  211.5000
# 973          67.0          C55 C57        S  221.7792
# 974          49.0              NaN        S   26.0000
# 986          25.0              NaN        C   26.0000
# ...

# %%
df.columns
df.columns[1]

#gets column names in sequence
# Out:
# 'Cabin'

# %%
df.Pclass.value_counts(sort=False)
#The result of value_counts is a Series; sort=False doesn’t sort the Series by values, so they appear in order.
df.Survived.value_counts(sort=False)
# Out:
#  0      549
#  1      342
# -888    418
# Name: Survived, dtype: int64

# %%
df.loc[df.Survived == -888, 'Survived'] = np.nan
#cleans the data for missing values
#This statement replaces invalid values with np.nan. 
#The expression df.birthwgt_lb > 20 yields a Series of type bool, where True indicates that the condition is true.
#When a boolean Series is used as an index, it selects only the elements that satisfy the condition.

# %%
df.describe()
#gets statistics for all numerical columns
df.Fare.describe()
df['Fare'].describe()
#gets statistics for given columns
df['Cabin'].describe()
# Out:
# count    1308.000000
# mean       33.295479
# std        51.758668
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max       512.329200
# Name: Fare, dtype: float64

# %%
df.describe()
# Out:
#                Age         Fare        Parch       Pclass        SibSp  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027     2.294882     0.498854
# std      14.413493    51.758668     0.865560     0.837836     1.041658
# min       0.170000     0.000000     0.000000     1.000000     0.000000
# 25%      21.000000     7.895800     0.000000     2.000000     0.000000
# 50%      28.000000    14.454200     0.000000     3.000000     0.000000
# 75%      39.000000    31.275000     0.000000     3.000000     1.000000
# max      80.000000   512.329200     9.000000     3.000000     8.000000
#
#          Survived
# count  891.000000
# mean     0.383838
# std      0.486592
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
df.mean()
#for mean of all cols
df['Age'].mean()
#for mean of col
# Out:
# 29.881137667304014

# %%
df.median()
#for median of all cols
df['Age'].median()
#for median of col
# Out:
# 28.0

# %%
#Dispersion Measure
df.max()#gives max of all cols
df.min()#gives min of all cols
# Out:
# pandas.core.series.Series

# %%
rng=df.Age.max()-df.Age.min()
print(rng)
# Out:
# 79.83

# %%
df.Fare.quantile(.25)#25 percentile
df.Fare.quantile(.5)#50 percentile
df.Fare.quantile(.75)#75 percentile
# Out:
# 31.275

# %%
df.Age.var()#gives variance of age
# Out:
# 207.74878655136456

# %%
df.Fare.std()#gives standard deviation of age
# Out:
# 51.758668239174156

# %%
# %matplotlib inline #gives plot inline
#box-whisker plot
df.Fare.plot(kind='box')

# %%
#Working with categorical data
df.describe(include='all')
# Out:
#                 Age        Cabin Embarked         Fare              Name  \
# count   1046.000000          295     1307  1308.000000              1309
# unique          NaN          186        3          NaN              1307
# top             NaN  C23 C25 C27        S          NaN  Kelly, Mr. James
# freq            NaN            6      914          NaN                 2
# mean      29.881138          NaN      NaN    33.295479               NaN
# std       14.413493          NaN      NaN    51.758668               NaN
# min        0.170000          NaN      NaN     0.000000               NaN
# 25%       21.000000          NaN      NaN     7.895800               NaN
# 50%       28.000000          NaN      NaN    14.454200               NaN
# 75%       39.000000          NaN      NaN    31.275000               NaN
# max       80.000000          NaN      NaN   512.329200               NaN
#
#               Parch       Pclass   Sex        SibSp    Survived    Ticket
# ...

# %%
df.Sex.value_counts()
#categorical column : Count
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts(normalize=True)
#categorical column : Proportion
# Out:
# male      0.644003
# female    0.355997
# Name: Sex, dtype: float64

# %%
df[df['Survived']=='NaN']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py:816: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-cb03a31a5b01> in <module>()
# ----> 1 df[df['Survived']=='NaN']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     877
#     878             with np.errstate(all='ignore'):
# --> 879                 res = na_op(values, other)
#     880             if is_scalar(res):
#     881                 raise TypeError('Could not compare {typ} type with Series'
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     816                     result = getattr(x, name)(y)
# ...

# %%
df[df.Survived!=-888].Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Pclass.value_counts(sort=False).plot(kind='bar')
#plots a bar graph for the feature value count

# %%
df.Pclass.value_counts(sort=False).plot(kind='bar',title='CLasswise Count',rot=0,color='c');
# ';' hides the <matplotlib.axes._subplots.AxesSubplot at 0x85b099b9b0> output

# %%
#Distributions

#using histogram
df.Age.plot(kind='hist',bins=20,color='c')

# %%
df.Age.plot(kind='kde',color='c')
#KDE plot with right skewness

# %%
df.Fare.plot(kind='hist',bins=20,color='c')

# %%
#Calculating Skewness
df.Fare.skew()
# Out:
# 4.367709134122921

# %%
df.Age.skew()
# Out:
# 0.40767455974362266

# %%
#feature on x and feature on y specified
df.plot.scatter(x='Age',y='Fare',title='Age vs Fare')

# %%
#feature on x and feature on y specified and alpha(0-1) used to set transparency
df.plot.scatter(x='Age',y='Fare',title='Age vs Fare',alpha=0.1)

# %%
#feature on x and feature on y specified and alpha(0-1) used to set transparency
df.plot.scatter(x='Pclass',y='Fare',title='Age vs Fare',alpha=0.1)

# %%
#groupby groups the rows by col 'Sex' and the Age column is selected for the group and describe gives the stats summary
df.groupby('Sex').Age.describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  388.0  28.687088  14.576962  0.17  19.0  27.0  38.0  76.0
# male    658.0  30.585228  14.280581  0.33  21.0  28.0  39.0  80.0

# %%
df.groupby('Pclass').Fare.median()
# Out:
# Pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: Fare, dtype: float64

# %%
df.groupby('Pclass')['Fare','Age'].median()
# Out:
#            Fare   Age
# Pclass
# 1       60.0000  39.0
# 2       15.0458  29.0
# 3        8.0500  24.0

# %%
#aggregation function in action, passed as a dicitonary of column and respective function to be applied to it.
df.groupby('Pclass').agg({'Fare':'mean','Age':'median'})
# Out:
#              Fare   Age
# Pclass
# 1       87.508992  39.0
# 2       21.179196  29.0
# 3       13.302889  24.0

# %%
#Complex Aggregation
aggre={
    'Fare':{
            'mean_fare':'mean',
            'median_fare':'median',
            'max_fare':max,
            'min_fare':min},
    'Age':{
           'median_age':'median',
           'max_age':max,
           'min_age':np.min,
           'range_age':lambda x: max(x)-min(x)}
      }

# %%
df.groupby('Pclass').agg(aggre)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#              Fare                                       Age                  \
#         mean_fare median_fare  max_fare min_fare median_age max_age min_age
# Pclass
# 1       87.508992     60.0000  512.3292      0.0       39.0    80.0    0.92
# 2       21.179196     15.0458   73.5000      0.0       29.0    70.0    0.67
# 3       13.302889      8.0500   69.5500      0.0       24.0    74.0    0.17
#
#
#        range_age
# Pclass
# 1          79.08
# 2          69.33
# 3          73.83

# %%
df[df.Survived!=-888].groupby(['Pclass','Embarked','Survived']).mean()
# Out:
#                                 Age        Fare     Parch     SibSp
# Pclass Embarked Survived
# 1      C        0         43.380952   78.841981  0.346154  0.153846
#                 1         35.905660  116.121754  0.305085  0.474576
#        Q        0         44.000000   90.000000  0.000000  2.000000
#                 1         33.000000   90.000000  0.000000  1.000000
#        S        0         43.845238   57.260926  0.283019  0.320755
#                 1         34.529091   79.750114  0.472973  0.513514
# 2      C        0         29.500000   25.418225  0.375000  0.625000
#                 1         16.875000   25.305100  0.666667  0.555556
#        Q        0         57.000000   12.350000  0.000000  0.000000
#                 1         30.000000   12.350000  0.000000  0.000000
#        S        0         33.603659   18.946591  0.125000  0.295455
#                 1         26.822027   21.926316  0.657895  0.500000
# ...

# %%
pd.crosstab(df.Sex,df.Pclass)

#uses Pandas function crosstab, takes 2 categorical features and returns as a cross table
# Out:
# Pclass    1    2    3
# Sex
# female  144  106  216
# male    179  171  493

# %%
pd.crosstab(df.Sex,df.Pclass).plot(kind='bar')

#uses Pandas function crosstab, takes 2 categorical features and returns as a cross table. Using plot to plot of a graph of crosstab

# %%
# pivot table

#index='row' , columns= col, values= attribute to fill cells with, aggfunc= function to apply to values

df.pivot_table(index='Sex',columns='Pclass',values='Age',aggfunc='mean')
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264

# %%
df.groupby(['Sex','Pclass']).Age.mean()
# gives similar result to pivot table
# Out:
# Sex     Pclass
# female  1         37.037594
#         2         27.499223
#         3         22.185329
# male    1         41.029272
#         2         30.815380
#         3         25.962264
# Name: Age, dtype: float64

# %%
df.groupby(['Sex','Pclass']).Age.mean().unstack()
#use unstack to get a tabular result
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264

# %%
# %%html
# <h1> DATA MUNGING </h1>
# Out:
# <h1> DATA MUNGING </h1>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 892 to 891
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1307 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
# Extract rows with no Embarked value, us isnull() function on column to get null value rows
df[df.Embarked.isnull()]
# Out:
#               Age Cabin Embarked  Fare  \
# PassengerId
# 62           38.0   B28      NaN  80.0
# 830          62.0   B28      NaN  80.0
#
#                                                   Name  Parch  Pclass     Sex  \
# PassengerId
# 62                                 Icard, Miss. Amelie      0       1  female
# 830          Stone, Mrs. George Nelson (Martha Evelyn)      0       1  female
#
#              SibSp  Survived  Ticket
# PassengerId
# 62               0         1  113572
# 830              0         1  113572

# %%
# freq of people at diff embarkment point
df.Embarked.value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
# getting values from dataframe of survived from each Embarkment point
pd.crosstab(df[df.Survived!=-888].Embarked,df[df.Survived!=-888].Survived)

# As we saw the most likely embarkment point where the passenger survived is "S"
# Out:
# Survived    0    1
# Embarked
# C          75   93
# Q          47   30
# S         427  217

# %%
# As the fare is 80 for both missing val rows then lets take median of Fare of group of PClass and Embarked, to get a 
# better understanding of where the Fare is closest to 80
df.groupby(['Pclass','Embarked']).Fare.median().unstack()
# Out:
# Embarked        C      Q       S
# Pclass
# 1         76.7292  90.00  52.000
# 2         15.3146  12.35  15.375
# 3          7.8958   7.75   8.050

# %%
# ways of imputing data

# using fillna function : takes first argument as data to replace Na with 'C', inplace attribute: True replaces in same DAtaFrame
# False creates a new copy of df with replaced values
# df.Embarked.fillna('S',inplace=True) : 

# using loc function to locate the null values and then replacing with given val
# df.loc[df.Embarked.isnull(),'Embarked']='S'

# %%
df.Embarked.fillna('C',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 892 to 891
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
df[df.Fare.isnull()]
# Out:
#               Age Cabin Embarked  Fare                Name  Parch  Pclass  \
# PassengerId
# 1044         60.5   NaN        S   NaN  Storey, Mr. Thomas      0       3
#
#               Sex  SibSp  Survived Ticket
# PassengerId
# 1044         male      0      -888   3701

# %%
# as passenger boarded at S and in class 3, we can take median of Fare where Class is 3 and Embarked is S

df.loc[df.Fare.isnull(),'Fare']=df[(df.Embarked=='S')&(df.Pclass==3)&(df.Sex=='male')&(df.Age>60)].Fare.median()

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Cabin, Embarked, Fare, Name, Parch, Pclass, Sex, SibSp, Survived, Ticket]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 892 to 891
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
# to set max rows to display

pd.options.display.max_rows=15

# %%
df[df.Age.isnull()]
# Out:
#              Age Cabin Embarked     Fare  \
# PassengerId
# 902          NaN   NaN        S   7.8958
# 914          NaN   NaN        S  31.6833
# 921          NaN   NaN        C  21.6792
# 925          NaN   NaN        S  23.4500
# 928          NaN   NaN        S   8.0500
# 931          NaN   NaN        S  56.4958
# 933          NaN   D34        S  26.5500
# ...          ...   ...      ...      ...
# 847          NaN   NaN        S  69.5500
# 850          NaN   C92        C  89.1042
# 860          NaN   NaN        C   7.2292
# 864          NaN   NaN        S  69.5500
# 869          NaN   NaN        S   9.5000
# 879          NaN   NaN        S   7.8958
# 889          NaN   NaN        S  23.4500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 902                                           Ilieff, Mr. Ylio      0       3
# 914                       Flegenheim, Mrs. Alfred (Antoinette)      0       1
# ...

# %%
df.Age.plot(kind='hist',bins=20)

# %%
#check mean age
df.Age.mean()
# Out:
# 29.881137667304014

# %%
df.groupby('Sex').Age.median()
# Out:
# Sex
# female    27.0
# male      28.0
# Name: Age, dtype: float64

# %%
df[df.Age.notnull()].boxplot('Age','Sex')

# %%
# To fill age according to sex
# df.groupby('Sex').Age.transform('median')
ef=df.groupby('Sex').Age.transform('median')
#df.Age.fillna(ef,inplace=True)

# %%
df[df.Age.notnull()].boxplot('Age','Pclass')

# %%
df.groupby('Pclass').Age.median()
# Out:
# Pclass
# 1    39.0
# 2    29.0
# 3    24.0
# Name: Age, dtype: float64

# %%
# for a better age prediciton, add a Title column to the dataset
# Insert data from function getTitle that takes name and gives title
def getTitle(name):
    get_name_with_title=name.split(',')[1]
    title=get_name_with_title.split('.')[0]
    return title.strip().lower()

# %%
df.Name.map(lambda x: getTitle(x)).unique()
# Out:
# array(['mr', 'mrs', 'miss', 'master', 'ms', 'col', 'rev', 'dr', 'dona',
#        'don', 'mme', 'major', 'lady', 'sir', 'mlle', 'capt',
#        'the countess', 'jonkheer'], dtype=object)

# %%
def getTitle(name):
    title_dict={'mr':'Mr', 'mrs':'Mrs', 'miss':'Miss', 'master':'Master', 'ms':'Miss', 'col':'Officer', 'rev':'Sir', 'dr':'Officer', 'dona':'Lady',
       'don':'Sir', 'mme':'Lady', 'major':'Officer', 'lady':'Lady', 'sir':'Sir', 'mlle':'Lady', 'capt' :'Officer',
       'the countess':'Lady', 'jonkheer':'Sir'}
    get_name_with_title=name.split(',')[1]
    title=get_name_with_title.split('.')[0]
    return title_dict[title.strip().lower()]

# %%
df['Name'].map(lambda x: getTitle(x)).unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Officer', 'Sir', 'Lady'],
#       dtype=object)

# %%
df['Title']=df['Name'].map(lambda x: getTitle(x))

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 892          34.5   NaN        Q   7.8292
# 893          47.0   NaN        S   7.0000
# 894          62.0   NaN        Q   9.6875
# 895          27.0   NaN        S   8.6625
# 896          22.0   NaN        S  12.2875
#
#                                                      Name  Parch  Pclass  \
# PassengerId
# 892                                      Kelly, Mr. James      0       3
# 893                      Wilkes, Mrs. James (Ellen Needs)      0       3
# 894                             Myles, Mr. Thomas Francis      0       2
# 895                                      Wirz, Mr. Albert      0       3
# 896          Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1       3
#
#                 Sex  SibSp  Survived   Ticket Title
# PassengerId
# 892            male      0      -888   330911    Mr
# 893          female      1      -888   363272   Mrs
# 894            male      0      -888   240276    Mr
# ...

# %%
df[df.Age.notnull()].boxplot('Age','Title')

# %%
df.Age.fillna(df.groupby('Title').Age.transform('median'),inplace=True)

# %%
df[df.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Cabin, Embarked, Fare, Name, Parch, Pclass, Sex, SibSp, Survived, Ticket, Title]
# Index: []

# %%
df.Age.mean()
# Out:
# 29.42946524064171

# %%
df.Age.median()
# Out:
# 29.0

# %%
df.Age.mode()
# Out:
# 0    29.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 892 to 891
# Data columns (total 12 columns):
# Age         1309 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# Title       1309 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 172.9+ KB

# %%
df.Age.plot(kind='hist',bins=20,edgecolor='b')

# %%
df[df.Age>70]
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 988          76.0   C46        S  78.8500
# 97           71.0    A5        C  34.6542
# 117          70.5   NaN        Q   7.7500
# 494          71.0   NaN        C  49.5042
# 631          80.0   A23        S  30.0000
# 852          74.0   NaN        S   7.7750
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 988          Cavendish, Mrs. Tyrell William (Julia Florence...      0       1
# 97                                   Goldschmidt, Mr. George B      0       1
# 117                                       Connors, Mr. Patrick      0       3
# 494                                    Artagaveytia, Mr. Ramon      0       1
# 631                       Barkworth, Mr. Algernon Henry Wilson      0       1
# 852                                        Svensson, Mr. Johan      0       3
#
#                 Sex  SibSp  Survived    Ticket Title
# PassengerId
# ...

# %%
df.Fare.plot(kind='hist',bins=20,edgecolor='b')

# %%
df.Fare.plot(kind='box')

# %%
df[df.Fare==df.Fare.max()]
# Out:
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 1235         58.0  B51 B53 B55        C  512.3292
# 259          35.0          NaN        C  512.3292
# 680          36.0  B51 B53 B55        C  512.3292
# 738          35.0         B101        C  512.3292
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1235         Cardeza, Mrs. James Warburton Martinez (Charlo...      1       1
# 259                                           Ward, Miss. Anna      0       1
# 680                         Cardeza, Mr. Thomas Drake Martinez      1       1
# 738                                     Lesurer, Mr. Gustave J      0       1
#
#                 Sex  SibSp  Survived    Ticket Title
# PassengerId
# 1235         female      0      -888  PC 17755   Mrs
# 259          female      0         1  PC 17755  Miss
# 680            male      0         1  PC 17755    Mr
# 738            male      0         1  PC 17755    Mr

# %%
#Transformation Example
LogFare = np.log(df.Fare+1.0)

# %%
LogFare.plot(kind='hist',bins=20)

# %%
#Binning
#we use Pandas qcut() for binning
# qcut() performs quantile type binning
# attributes first the data, second the no. of bins
pd.qcut(df.Fare,4)
# Out:
# PassengerId
# 892     (-0.001, 7.896]
# 893     (-0.001, 7.896]
# 894     (7.896, 14.454]
# 895     (7.896, 14.454]
# 896     (7.896, 14.454]
# 897     (7.896, 14.454]
# 898     (-0.001, 7.896]
#              ...
# 885     (-0.001, 7.896]
# 886    (14.454, 31.275]
# 887     (7.896, 14.454]
# 888    (14.454, 31.275]
# 889    (14.454, 31.275]
# 890    (14.454, 31.275]
# 891     (-0.001, 7.896]
# Name: Fare, Length: 1309, dtype: category
# Categories (4, interval[float64]): [(-0.001, 7.896] < (7.896, 14.454] < (14.454, 31.275] < (31.275, 512.329]]

# %%
pd.qcut(df.Fare,4,labels=['very low','medium','high','very high'])
#this is dicretization converting numerical data into categorical data
# Out:
# PassengerId
# 892    very low
# 893    very low
# 894      medium
# 895      medium
# 896      medium
# 897      medium
# 898    very low
#          ...
# 885    very low
# 886        high
# 887      medium
# 888        high
# 889        high
# 890        high
# 891    very low
# Name: Fare, Length: 1309, dtype: category
# Categories (4, object): [very low < medium < high < very high]

# %%
pd.qcut(df.Fare,4,labels=['very low','medium','high','very high']).value_counts().plot(kind='bar')
#this is dicretization converting numerical data into categorical data

# %%
# storing the bins in new feature
df['Fare_bin']=pd.qcut(df.Fare,4,labels=['very low','medium','high','very high'])

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 892          34.5   NaN        Q   7.8292
# 893          47.0   NaN        S   7.0000
# 894          62.0   NaN        Q   9.6875
# 895          27.0   NaN        S   8.6625
# 896          22.0   NaN        S  12.2875
#
#                                                      Name  Parch  Pclass  \
# PassengerId
# 892                                      Kelly, Mr. James      0       3
# 893                      Wilkes, Mrs. James (Ellen Needs)      0       3
# 894                             Myles, Mr. Thomas Francis      0       2
# 895                                      Wirz, Mr. Albert      0       3
# 896          Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1       3
#
#                 Sex  SibSp  Survived   Ticket Title  Fare_bin
# PassengerId
# 892            male      0      -888   330911    Mr  very low
# 893          female      1      -888   363272   Mrs  very low
# ...

# %%
#Feature Engineering

#creating a new feature 'AgeState' using numpy where function

#where(condition,on_cond_true,on_cond_false)

df['AgeState']=np.where(df.Age<18,'Child','Adult')

# %%
df['AgeState'].value_counts()
# Out:
# Adult    1147
# Child     162
# Name: AgeState, dtype: int64

# %%
pd.crosstab(df[df.Survived!=-888].AgeState,df[df.Survived!=-888].Survived)
# Out:
# Survived    0    1
# AgeState
# Adult     495  279
# Child      54   63

# %%
# creating a family size feature
df['FamilySize']=df.Parch+df.SibSp+1

# %%
df.FamilySize.plot(kind='hist')

# %%
df.loc[df.FamilySize==df.FamilySize.max(),['Age','Survived','FamilySize']]
# Out:
#               Age  Survived  FamilySize
# PassengerId
# 1080         22.0      -888          11
# 1234         29.0      -888          11
# 1252         14.5      -888          11
# 1257         35.5      -888          11
# 160           4.0         0          11
# 181          22.0         0          11
# 202          29.0         0          11
# 325          29.0         0          11
# 793          22.0         0          11
# 847          29.0         0          11
# 864          22.0         0          11

# %%
pd.crosstab(df[df.Survived!=-888].FamilySize,df[df.Survived!=-888].Survived)
# Out:
# Survived      0    1
# FamilySize
# 1           374  163
# 2            72   89
# 3            43   59
# 4             8   21
# 5            12    3
# 6            19    3
# 7             8    4
# 8             6    0
# 11            7    0

# %%
# creating a new feature 'IsMother' as mothers were given more priority over men
df['IsMother']=np.where((df.Age>18)&(df.Sex=='female')&(df.Title!='Miss')&(df.Parch>0),1,0)

# %%
df['IsMother'].value_counts()
# Out:
# 0    1224
# 1      85
# Name: IsMother, dtype: int64

# %%
pd.crosstab(df[df.Survived!=-888].IsMother,df[df.Survived!=-888].Survived)
# Out:
# Survived    0    1
# IsMother
# 0         533  303
# 1          16   39

# %%
# working with Deck information

df[df.Cabin.notnull()].Cabin
# Out:
# PassengerId
# 904                B45
# 906                E31
# 916    B57 B59 B63 B66
# 918                B36
# 920                A21
# 926                C78
# 933                D34
#             ...
# 863                D17
# 868                A24
# 872                D35
# 873        B51 B53 B55
# 880                C50
# 888                B42
# 890               C148
# Name: Cabin, Length: 295, dtype: object

# %%
df.Cabin.unique()
# Out:
# array([nan, 'B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D34',
#        'D19', 'A9', 'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116',
#        'F', 'A29', 'G6', 'C6', 'C28', 'C51', 'E46', 'C54', 'C97', 'D22',
#        'B10', 'F4', 'E45', 'E52', 'D30', 'B58 B60', 'E34', 'C62 C64',
#        'A11', 'B11', 'C80', 'F33', 'C85', 'D37', 'C86', 'D21', 'C89',
#        'F E46', 'A34', 'D', 'B26', 'C22 C26', 'B69', 'C32', 'B78',
#        'F E57', 'F2', 'A18', 'C106', 'B51 B53 B55', 'D10 D12', 'E60',
#        'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24', 'D28', 'B41', 'C7',
#        'D40', 'D38', 'C105', 'C123', 'C103', 'D56', 'A6', 'D33', 'B30',
#        'C52', 'B28', 'C83', 'F G73', 'A5', 'D26', 'C110', 'E101', 'F E69',
#        'D47', 'B86', 'C2', 'E33', 'B19', 'A7', 'C49', 'A32', 'B4', 'B80',
#        'A31', 'D36', 'C93', 'D35', 'C87', 'B77', 'E67', 'B94', 'C125',
# ...

# %%
df[df.Cabin=='T']
# Out:
#               Age Cabin Embarked  Fare                          Name  Parch  \
# PassengerId
# 340          45.0     T        S  35.5  Blackwell, Mr. Stephen Weart      0
#
#              Pclass   Sex  SibSp  Survived  Ticket Title   Fare_bin AgeState  \
# PassengerId
# 340               1  male      0         0  113784    Mr  very high    Adult
#
#              FamilySize  IsMother
# PassengerId
# 340                   1         0

# %%
# removing the value T as it might be there by mistake
df.loc[df.Cabin=='T','Cabin']=np.nan

# %%
def get_deck(cabin):
    return np.where(pd.notnull(cabin),str(cabin)[0].upper(),'Z')
df['Deck']=df['Cabin'].map(lambda x: get_deck(x))

# %%
df.tail()
# Out:
#               Age Cabin Embarked   Fare  \
# PassengerId
# 887          27.0   NaN        S  13.00
# 888          19.0   B42        S  30.00
# 889          22.0   NaN        S  23.45
# 890          26.0  C148        C  30.00
# 891          32.0   NaN        Q   7.75
#
#                                                  Name  Parch  Pclass     Sex  \
# PassengerId
# 887                             Montvila, Rev. Juozas      0       2    male
# 888                      Graham, Miss. Margaret Edith      0       1  female
# 889          Johnston, Miss. Catherine Helen "Carrie"      2       3  female
# 890                             Behr, Mr. Karl Howell      0       1    male
# 891                               Dooley, Mr. Patrick      0       3    male
#
#              SibSp  Survived      Ticket Title  Fare_bin AgeState  FamilySize  \
# PassengerId
# 887              0         0      211536   Sir    medium    Adult           1
# ...

# %%
df['Deck'].value_counts()
# Out:
# Z    1015
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# Name: Deck, dtype: int64

# %%
pd.crosstab(df[df.Survived!=-888].Deck,df[df.Survived!=-888].Survived)
# Out:
# Survived    0    1
# Deck
# A           8    7
# B          12   35
# C          24   35
# D           8   25
# E           8   24
# F           5    8
# G           2    2
# Z         482  206

# %%
#Categorical Feature Encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 892 to 891
# Data columns (total 17 columns):
# Age           1309 non-null float64
# Cabin         294 non-null object
# Embarked      1309 non-null object
# Fare          1309 non-null float64
# Name          1309 non-null object
# Parch         1309 non-null int64
# Pclass        1309 non-null int64
# Sex           1309 non-null object
# SibSp         1309 non-null int64
# Survived      1309 non-null int64
# Ticket        1309 non-null object
# Title         1309 non-null object
# Fare_bin      1309 non-null category
# AgeState      1309 non-null object
# FamilySize    1309 non-null int64
# IsMother      1309 non-null int32
# Deck          1309 non-null object
# dtypes: category(1), float64(2), int32(1), int64(5), object(8)
# memory usage: 210.2+ KB

# %%
df['IsMale']=np.where(df.Sex=='male',1,0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 892 to 891
# Data columns (total 18 columns):
# Age           1309 non-null float64
# Cabin         294 non-null object
# Embarked      1309 non-null object
# Fare          1309 non-null float64
# Name          1309 non-null object
# Parch         1309 non-null int64
# Pclass        1309 non-null int64
# Sex           1309 non-null object
# SibSp         1309 non-null int64
# Survived      1309 non-null int64
# Ticket        1309 non-null object
# Title         1309 non-null object
# Fare_bin      1309 non-null category
# AgeState      1309 non-null object
# FamilySize    1309 non-null int64
# IsMother      1309 non-null int32
# Deck          1309 non-null object
# IsMale        1309 non-null int32
# dtypes: category(1), float64(2), int32(2), int64(5), object(8)
# memory usage: 215.3+ KB

# %%
# PAndas function get_dummies() uses one hot encoding to encode categorical data
# get_dummies() is passed the df as first argument, and 
#the columns on which to apply encoding as columns attribute in an array of col names

df=pd.get_dummies(df,columns=['Deck','Pclass','Title','Fare_bin','Embarked','AgeState'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 892 to 891
# Data columns (total 39 columns):
# Age                   1309 non-null float64
# Cabin                 294 non-null object
# Fare                  1309 non-null float64
# Name                  1309 non-null object
# Parch                 1309 non-null int64
# Sex                   1309 non-null object
# SibSp                 1309 non-null int64
# Survived              1309 non-null int64
# Ticket                1309 non-null object
# FamilySize            1309 non-null int64
# IsMother              1309 non-null int32
# IsMale                1309 non-null int32
# Deck_A                1309 non-null uint8
# Deck_B                1309 non-null uint8
# Deck_C                1309 non-null uint8
# Deck_D                1309 non-null uint8
# Deck_E                1309 non-null uint8
# Deck_F                1309 non-null uint8
# Deck_G                1309 non-null uint8
# ...

# %%
# Dropping and Reordering the dataframe

#use the drop() function to drop columns from dataframe
columns=['Cabin','Name','Ticket','Parch','SibSp','Sex']
df.drop(columns,axis=1,inplace=True)

# %%
#reordering columns

columns=[col for col in df.columns if col!='Survived']
columns +=['Survived']

# %%
df=df[columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 892 to 891
# Data columns (total 33 columns):
# Age                   1309 non-null float64
# Fare                  1309 non-null float64
# FamilySize            1309 non-null int64
# IsMother              1309 non-null int32
# IsMale                1309 non-null int32
# Deck_A                1309 non-null uint8
# Deck_B                1309 non-null uint8
# Deck_C                1309 non-null uint8
# Deck_D                1309 non-null uint8
# Deck_E                1309 non-null uint8
# Deck_F                1309 non-null uint8
# Deck_G                1309 non-null uint8
# Deck_Z                1309 non-null uint8
# Pclass_1              1309 non-null uint8
# Pclass_2              1309 non-null uint8
# Pclass_3              1309 non-null uint8
# Title_Lady            1309 non-null uint8
# Title_Master          1309 non-null uint8
# Title_Miss            1309 non-null uint8
# Title_Mr              1309 non-null uint8
# ...

# %%
# Saving and writing a dataframe to a file

processed_data_path=os.path.join(os.path.pardir,'data','processed')
train_data_path=os.path.join(processed_data_path,'train.csv')
test_data_path=os.path.join(processed_data_path,'test.csv')

# %%
# writing data to csv file
df.loc[df.Survived!=-888].to_csv(train_data_path)
columns=[col for col in df.columns if col!='Survived']
df.loc[df.Survived!=-888,columns].to_csv(test_data_path)

# %%
# %%html
# <h1>Reproducable Script</h1>
# Out:
# <h1>Reproducable Script</h1>

# %%
get_processed_data_script=os.path.join(os.path.pardir,'src','data','get_processed_data.py')

# %%
# %%writefile $get_processed_data_script
# import pandas as pd,numpy as np,os
# def read_data():
#     #setting path of the files
#     raw_data_path=os.path.join(os.path.pardir,'data','raw')
#     train_data_path=os.path.join(raw_data_path,'train.csv')
#     test_data_path=os.path.join(raw_data_path,'test.csv')
#     #read data and set all default values
#     train_df=pd.read_csv(train_data_path,index_col='PassengerId')
#     test_df=pd.read_csv(test_data_path,index_col='PassengerId')
#     test_df['Survived']=-888
#     df=pd.concat((test_df,train_df),axis=0)
#     return df
# def process_data(df):
#     #using method chaning
#     return (df
#             #use assign method to create new feature
#             .assign(Title=lambda x: x.Name.map(getTitle))
#             #pipe method used to apply function on dataframe
#             .pipe(fill_missing_vals)
#             #feature addition
#             .assign(Fare_bin=lambda x: pd.qcut(x.Fare,4,labels=['very low','medium','high','very high']))
#             .assign(AgeState=lambda x: np.where(x.Age<18,'Child','Adult'))
#             .assign(FamilySize=lambda x: x.Parch+x.SibSp+1 )
#             .assign(IsMother=lambda x:np.where((x.Age>18)&(x.Sex=='female')&(x.Title!='Miss')&(x.Parch>0),1,0) )
#             .assign(Cabin=lambda x: np.where(x.Cabin=='T',np.nan,x.Cabin))
#             .assign(Deck=lambda x: x['Cabin'].map(get_deck))
#             #feature encoding
#             .assign(IsMale=lambda x: np.where(x.Sex=='male',1,0))
#             .pipe(pd.get_dummies,columns=['Deck','Pclass','Title','Fare_bin','Embarked','AgeState'])
#             #drop columns, method chaining doesn't require inplace attribute
#             .drop(['Cabin','Name','Ticket','Parch','SibSp','Sex'],axis=1)
#             .pipe(reorder_column))
#
# def fill_missing_vals(df):
#     #Embarked missing values filled
#     df.Embarked.fillna('C',inplace=True)
#     #Fare missing values filled
#     df.loc[df.Fare.isnull(),'Fare']=df[(df.Embarked=='S')&(df.Pclass==3)&(df.Sex=='male')&(df.Age>60)].Fare.median()
#     #Age missing values filled
#     df.Age.fillna(df.groupby('Title').Age.transform('median'),inplace=True)
#     return df
#
# def getTitle(name):
#     title_dict={'mr':'Mr', 'mrs':'Mrs', 'miss':'Miss', 'master':'Master', 'ms':'Miss', 'col':'Officer', 'rev':'Sir', 'dr':'Officer', 'dona':'Lady',
#        'don':'Sir', 'mme':'Lady', 'major':'Officer', 'lady':'Lady', 'sir':'Sir', 'mlle':'Lady', 'capt' :'Officer',
#        'the countess':'Lady', 'jonkheer':'Sir'}
#     get_name_with_title=name.split(',')[1]
#     title=get_name_with_title.split('.')[0]
#     return title_dict[title.strip().lower()]
# def get_deck(cabin):
#     return np.where(pd.notnull(cabin),str(cabin)[0].upper(),'Z')
#
# def reorder_column(df):
#     columns=[col for col in df.columns if col!='Survived']
#     columns +=['Survived']
#     df=df[columns]
#     return df
#
# def write_data(df):
#     # Saving and writing a dataframe to a file
#     processed_data_path=os.path.join(os.path.pardir,'data','processed')
#     train_data_path=os.path.join(processed_data_path,'train.csv')
#     test_data_path=os.path.join(processed_data_path,'test.csv')
#     # writing data to csv file
#     df.loc[df.Survived!=-888].to_csv(train_data_path)
#     columns=[col for col in df.columns if col!='Survived']
#     df.loc[df.Survived!=-888,columns].to_csv(test_data_path)
#
# if __name__=='__main__':
#     df=read_data()
#     df=process_data(df)
#     write_data(df)
# Out:
# Overwriting ..\src\data\get_processed_data.py

# %%
! python  $get_processed_data_script

# %%
import matplotlib.pyplot as plt

# %%
#subplots arguments
# row =1
#col= 2
#figsize= 14 inches wide and 3 inch in height

f, (ax1,ax2)=plt.subplots(1,2,figsize=(14,3))

ax1.hist(df.Age)

ax2.hist(df.Fare)
plt.show()
